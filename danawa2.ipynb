# %%
#!pip install selenium
#quot from #https://blog.naver.com/PostView.nhn?blogId=jaehong7719&logNo=221964071872
from selenium import webdriver
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'http://search.danawa.com/dsearch.php?query=마우스&tab=main'
driver.get(url)

# %%
from bs4 import BeautifulSoup

# %%
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')

# %%
prod_items= soup.select('div.main_prodlist > ul.product_list > li.prod_item')
prod_items
# Out:
# [<li class="prod_item" id="productItem5781468">
#  <input id="productItem_categoryInfo_5781468" type="hidden" value="PC 주요 부품_마우스"/>
#  <input id="min_price_5781468" type="hidden" value="20790"/>
#  <div class="prod_main_info">
#  <div class="thumb_image">
#  <a class="thumb_link" href="http://prod.danawa.com/info/?pcode=5781468&amp;keyword=마우스&amp;cate=112787" id="thumbLink_5781468" onmousedown="_trkEventLog('통합검색_상품블로그_유입');" target="_blank">
#  <img alt="TRON G10PRO reborn 3330 RGB 게이밍마우스" class="click_log_product_standard_img_" src="http://img.danawa.com/prod_img/500000/468/781/img/5781468_1.jpg?shrink=160:160&amp;_v=20200703110411"/>
#  </a>
#  <a class="btn_view_zoom" data-assemblygallerycategory="N" href="#" id="imageZoom_5781468" onclick="return false;">
#  <span class="ico i_zoom_vw"></span>이미지보기
#  							</a>
#  <a class="btn_view_video" href="#" id="imageVideo_5781468" onclick="return false;">
#  <span class="badge_vdo">동영상</span>
#  </a>
# ...

# %%
title = prod_items[0].select('p.prod_name > a')[0].text.strip()
print(title)
# Out:
# MAXTILL TRON G10PRO reborn 3330 RGB 게이밍마우스

# %%
spec_list = prod_items[0].select('div.spec_list')[0].text.strip()
spec_list
# Out:
# '마우스 / 광 / DPI+5버튼 / 유선 / USB / 상하 / 센서: PMW-3330 / 14400DPI / 8000FPS / 가속도 30G / S/W 매크로 / RGB라이트 / 무광 UV코팅 / 게이밍 마우스 / 금도금USB단자 / 소프트웨어 지원 / 내장 메모리 / OMRON 스위치 / 123mm / 66mm / 38mm / 90g / 150IPS'

# %%
price =prod_items[0].select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(",","")
price
# Out:
# '20790'

# %%
def get_prod_items(prod_items):
    prod_data = []
    for prod_item in prod_items:
        try:
            title = prod_items[0].select('p.prod_name > a')[0].text.strip()
        except:
            title = ''
        try:
            spec_list = prod_items[0].select('div.spec_list')[0].text.strip()
        except:
            spec_list = ''
        try:
            price =prod_items[0].select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(",","")
        except:
            price = 0
        prod_data.append([title,spec_list,price])
    return prod_data

# %%
prod_items= soup.select('div.main_prodlist > ul.product_list > li.prod_item')
prod_data = get_prod_items(prod_items)
print(len(prod_data))
# Out:
# 41

# %%
def get_search_page_url(keyword,page):
    return 'http://search.danawa.com/dsearch.php?query={}&volumeType=allvs&page={}\&limit=30&sort=saveDESC&list&boost=true&addDelivery=N&tab=goods&\tab=goods'.format(keyword,page)
keyword = '마우스'
page = 1
url = get_search_page_url(keyword,page)
print(url)
# Out:
# http://search.danawa.com/dsearch.php?query=마우스&volumeType=allvs&page=1\&limit=30&sort=saveDESC&list&boost=true&addDelivery=N&tab=goods&	ab=goods

# %%
import time
from tqdm import tqdm_notebook
total_page = 10
for page in tqdm_notebook(range(1,total_page + 1)):
    time.sleep(5)
# Out:
# <ipython-input-24-3c400cf7c0cb>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for page in tqdm_notebook(range(1,total_page + 1)):
# ...
