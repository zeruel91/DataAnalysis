# %% [markdown]
# <a href="https://colab.research.google.com/github/zeruel91/DataAnalysis/blob/main/face2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pillow      # 파이썬에서 사진 컨트롤
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (7.0.0)

# %%
pip install requests    # 웹 전송/수신
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.10)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg  # jpg 등 의 이미지 파일 다루는 모듈

# %%
img = mpimg.imread('igun.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('igun.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files=files, headers=headers)

# %%
import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent=4, sort_keys = False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 450,
#             "height": 500
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 178,
#                 "y": 110,
#                 "width": 95,
#                 "height": 95
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 205,
#                     "y": 132
#                 },
#                 "rightEye": {
#                     "x": 248,
#                     "y": 135
#                 },
#                 "nose": {
#                     "x": 227,
#                     "y": 163
#                 },
#                 "leftMouth": {
#                     "x": 207,
#                     "y": 189
#                 },
#                 "rightMouth": {
#                     "x": 241,
#                     "y": 190
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 1.0
#             },
#             "age": {
#                 "value": "35~39",
#                 "confidence": 0.548819
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.986052
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999861
#             }
#         }
#     ]
# }

# %% [markdown]
# ##### 간단한 문법 정리 #####

# %%
dict_sample = {'Name':'pinkwink', 'Age':'None', 'Class':['beginner','blog']}

# %%
dict_sample
# Out:
# {'Age': 'None', 'Class': ['beginner', 'blog'], 'Name': 'pinkwink'}

# %%
dict_sample.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict_sample.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict_sample.get('Name')
# Out:
# 'pinkwink'

# %%
dict_sample.get('Age')
# Out:
# 'None'

# %%
dict_sample.get('ABC')

# %%
customer = {
    'id':'0001',
    'name':'홍길동',
    'history': [
                {'date':'2019-03-01','log':True},
                {'date':'2019-03-02','log':False},
    ]
}

# %%
import json

json_test = json.dumps(customer, indent = 4, ensure_ascii=False)
            # json.dump 를 사용하여 json데이터 생성
print(json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %%
import requests

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('trump.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files=files, headers=headers)

detect_result = json.loads(response.text)

# %%
detect_result.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
detect_result['faces']
# Out:
# [{'age': {'confidence': 0.210486, 'value': '23~27'},
#   'emotion': {'confidence': 0.991112, 'value': 'smile'},
#   'gender': {'confidence': 0.999943, 'value': 'male'},
#   'landmark': {'leftEye': {'x': 242, 'y': 249},
#    'leftMouth': {'x': 239, 'y': 364},
#    'nose': {'x': 289, 'y': 321},
#    'rightEye': {'x': 362, 'y': 257},
#    'rightMouth': {'x': 356, 'y': 369}},
#   'pose': {'confidence': 0.999931, 'value': 'frontal_face'},
#   'roi': {'height': 241, 'width': 241, 'x': 186, 'y': 193}}]

# %%
detect_result['faces'][0]
# Out:
# {'age': {'confidence': 0.210486, 'value': '23~27'},
#  'emotion': {'confidence': 0.991112, 'value': 'smile'},
#  'gender': {'confidence': 0.999943, 'value': 'male'},
#  'landmark': {'leftEye': {'x': 242, 'y': 249},
#   'leftMouth': {'x': 239, 'y': 364},
#   'nose': {'x': 289, 'y': 321},
#   'rightEye': {'x': 362, 'y': 257},
#   'rightMouth': {'x': 356, 'y': 369}},
#  'pose': {'confidence': 0.999931, 'value': 'frontal_face'},
#  'roi': {'height': 241, 'width': 241, 'x': 186, 'y': 193}}

# %%
detect_result['faces'][0]['roi']
# Out:
# {'height': 241, 'width': 241, 'x': 186, 'y': 193}

# %%
detect_result['faces'][0]['gender']
# Out:
# {'confidence': 0.999943, 'value': 'male'}

# %%
detect_result['faces'][0]['age']
# Out:
# {'confidence': 0.210486, 'value': '23~27'}

# %%
detect_result['faces'][0]['emotion']
# Out:
# {'confidence': 0.991112, 'value': 'smile'}

# %%
x ,y , w , h = detect_result['faces'][0]['roi'].values()
gender, gen_c = detect_result['faces'][0]['gender'].values()
emotion, emotion_c = detect_result['faces'][0]['emotion'].values()
age, age_c = detect_result['faces'][0]['age'].values()

# %%
annotation = gender + ':' + str(gen_c) + '\n' + emotion + ':' + str(emotion_c) + '\n'+ age + ":"+str(age_c)

# %%
print(annotation)
# Out:
# male:0.999943
# smile:0.991112
# 23~27:0.210486

# %%
import matplotlib.patches as patches

img = mpimg.imread('igun.jpg')

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img)
rect_face = patches.Rectangle((x,y), w, h,
                              linewidth=5,
                              edgecolor= 'r',
                              facecolor='none')
ax.add_patch(rect_face)

plt.text(10,400,annotation, wrap=True, fontsize = 17, color='white')
plt.show()
