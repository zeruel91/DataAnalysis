# %% [markdown]
# <a href="https://colab.research.google.com/github/zeruel91/DataAnalysis/blob/main/Naverclover_face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **얼굴 인식해서 닮은꼴 연예인 찾기 **

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (7.0.0)

# %% [markdown]
# 파이썬에서 사진을 컨트롤하는 라이브러리

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.10)

# %% [markdown]
# 웹 전송/수신

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg    #jpg등의 이미지 파일 다루는 모듈

# %%
img = mpimg.imread('IMG_1814 엄정민 반.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
client_id = "PcadxlHpoofakp4E0Kz5"
client_secret = "P0qDLr6sEW"

# %%
import requests

url = "https://openapi.naver.com/v1/vision/face"    #celebrity는 유명인, face는 각종 얼굴인식 정보
files = {"image":open("IMG_1814 엄정민 반.jpg", "rb")}
headers = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}

response = requests.post(url, files=files,headers=headers)

# %%
import json

parsed = json.loads(response.text)
print(json.dumps(parsed, indent=4, sort_keys = False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 827,
#             "height": 1102
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 230,
#                 "y": 294,
#                 "width": 368,
#                 "height": 368
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 319,
#                     "y": 400
#                 },
#                 "rightEye": {
#                     "x": 496,
#                     "y": 400
#                 },
#                 "nose": {
#                     "x": 407,
#                     "y": 501
#                 },
#                 "leftMouth": {
#                     "x": 336,
#                     "y": 574
#                 },
#                 "rightMouth": {
#                     "x": 475,
#                     "y": 573
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999719
#             },
#             "age": {
#                 "value": "16~20",
#                 "confidence": 1.0
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.999999
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.999345
#             }
#         }
#     ]
# }

# %% [markdown]
# -여기서 쓰이는 간단한 문법 정리-

# %% [markdown]
# 딕셔너리

# %%
dict_sample = {'Name':'pinkwink','Age':'None','Class':['beginner','blog']}

# %%
dict_sample
# Out:
# {'Age': 'None', 'Class': ['beginner', 'blog'], 'Name': 'pinkwink'}

# %%
dict_sample.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict_sample.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict_sample.get("Name")
# Out:
# 'pinkwink'

# %%
dict_sample.get('Age')
# Out:
# 'None'

# %%
dict_sample.get("ABC")

# %%
customer = {
    'id':'0001',
    'name':'홍길동',
    'history':[
               {'date':'2019-03-01', 'log':True},
               {'date':'2019-03-02', 'log':False},
               
    ]
}

# %%
import json
json_test = json.dumps(customer,indent = 4, ensure_ascii=False)    #json.dump를 사용하여 json데이터 생성
print(json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %% [markdown]
# 결과 꾸미기

# %%
import requests
import json

url = "https://openapi.naver.com/v1/vision/face"
files = {"image":open("IMG_1814 엄정민 반.jpg", "rb")}
headers = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}

response = requests.post(url, files=files,headers=headers)

# %%
import requests
import json

url = "https://openapi.naver.com/v1/vision/face"
files = {"image":open("유재석.jpg", "rb")}
headers = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}

response = requests.post(url, files=files,headers=headers)
detect_result = json.loads(response.text)
parsed = json.loads(response.text)
print(json.dumps(parsed, indent=4, sort_keys = False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 550,
#             "height": 634
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 191,
#                 "y": 118,
#                 "width": 167,
#                 "height": 167
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 234,
#                     "y": 158
#                 },
#                 "rightEye": {
#                     "x": 308,
#                     "y": 157
#                 },
#                 "nose": {
#                     "x": 274,
#                     "y": 204
#                 },
#                 "leftMouth": {
#                     "x": 240,
#                     "y": 236
#                 },
#                 "rightMouth": {
#                     "x": 312,
#                     "y": 233
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999987
#             },
#             "age": {
#                 "value": "45~49",
#                 "confidence": 0.299446
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.99832
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.998393
#             }
#         }
#     ]
# }

# %%
x, y, w, h = detect_result['faces'][0]["roi"].values()
gender, gen_confidence = detect_result['faces'][0]['gender'].values()
emotion, emotion_confidence = detect_result['faces'][0]['emotion'].values()
age, age_confidence = detect_result['faces'][0]['age'].values()

# %%
annotation1 = gender + " : " + str(gen_confidence) + "\n" + emotion + " : " + str(emotion_confidence) + "\n" + age + " : " + str(age_confidence)

# %%
print(annotation1)
# Out:
# male : 0.999987
# smile : 0.99832
# 45~49 : 0.299446

# %%
import matplotlib.patches as patches

img1 =mpimg.imread('유재석.jpg')

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img)
rect_face = patches.Rectangle((x,y),w,h,
                              linewidth=5,
                              edgecolor='r',
                              facecolor='none')
ax.add_patch(rect_face)

plt.text(10,400,annotation1,wrap=True,fontsize=17,color='blue')
plt.show()

# %% [markdown]
# 여러사람의 얼굴 인식

# %%
import matplotlib.patches as patches

img = mpimg.imread('가족사진.jpg')

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img)

for each in detect_result['faces']:
  x ,y , w , h = each['roi'].values()
  gender, gen_c = each['gender'].values()
  emotion, emotion_c = each['emotion'].values()
  age, age_c = each['age'].values()

  rect_face = patches.Rectangle((x,y), w, h,
                                linewidth=3,
                                edgecolor= 'r',
                                facecolor='none')
  ant_letter = gender + ', ' + emotion + ', ' + age
  plt.text(x, y+h+40, ant_letter, size = 12, color = 'yellow')
  ax.add_patch(rect_face)

plt.show()
